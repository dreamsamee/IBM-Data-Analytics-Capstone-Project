# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork928-2023-01-01">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Data Visualization Lab**

# %% [markdown]
# Estimated time needed: **45 to 60** minutes

# %% [markdown]
# In this assignment you will be focusing on the visualization of data.
#
# The data set will be presented to you in the form of a RDBMS.
#
# You will have to use SQL queries to extract the data.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# -   Visualize the distribution of data.
#
# -   Visualize the relationship between two features.
#
# -   Visualize composition of data.
#
# -   Visualize comparison of data.

# %% [markdown]
# <hr>

# %% [markdown]
# ## Demo: How to work with database

# %% [markdown]
# Download database file.

# %%
# !wget https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m4_survey_data.sqlite
# Out:
# --2024-04-01 16:28:22--  https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m4_survey_data.sqlite
# Resolving cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)... 169.63.118.104, 169.63.118.104
# Connecting to cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)|169.63.118.104|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 36679680 (35M) [application/octet-stream]
# Saving to: ‘m4_survey_data.sqlite’
#
# m4_survey_data.sqli 100%[===================>]  34.98M  41.9MB/s    in 0.8s
#
# 2024-04-01 16:28:24 (41.9 MB/s) - ‘m4_survey_data.sqlite’ saved [36679680/36679680]

# %% [markdown]
# Connect to the database.

# %%
import sqlite3
conn = sqlite3.connect("m4_survey_data.sqlite") # open a database connection
print("Connection Established")
# Out:
# Connection Established

# %% [markdown]
# Import pandas module.

# %%
import pandas as pd

# %% [markdown]
# ## Demo: How to run an sql query

# %%
# print how many rows are there in the table named 'master'
QUERY = """
SELECT COUNT(*)
FROM master
"""
# the read_sql_query runs the sql query and returns the data as a dataframe
df = pd.read_sql_query(QUERY,conn)
df.head()
# Out:
#    COUNT(*)
# 0     11398

# %% [markdown]
# ## Demo: How to list all tables

# %%
# print all the tables names in the database
QUERY = """
SELECT name as Table_Name FROM
sqlite_master WHERE
type = 'table'
"""
# the read_sql_query runs the sql query and returns the data as a dataframe
pd.read_sql_query(QUERY,conn)
# Out:
#                 Table_Name
# 0                 EduOther
# 1                  DevType
# 2                  LastInt
# 3               JobFactors
# 4                 WorkPlan
# 5            WorkChallenge
# 6       LanguageWorkedWith
# 7   LanguageDesireNextYear
# 8       DatabaseWorkedWith
# 9   DatabaseDesireNextYear
# 10      PlatformWorkedWith
# 11  PlatformDesireNextYear
# 12      WebFrameWorkedWith
# 13  WebFrameDesireNextYear
# 14      MiscTechWorkedWith
# 15  MiscTechDesireNextYear
# 16              DevEnviron
# 17              Containers
# 18               SOVisitTo
# 19            SONewContent
# 20                  Gender
# 21               Sexuality
# 22               Ethnicity
# 23                  master

# %% [markdown]
# ## Demo: How to run a group by query

# %%
QUERY = """
SELECT Age,COUNT(*) as count
FROM master
group by age
order by age
"""
pd.read_sql_query(QUERY,conn)
# Out:
#      Age  count
# 0    NaN    287
# 1   16.0      3
# 2   17.0      6
# 3   18.0     29
# 4   19.0     78
# 5   20.0    109
# 6   21.0    203
# 7   22.0    406
# 8   23.0    581
# 9   24.0    679
# 10  25.0    738
# 11  26.0    720
# 12  27.0    724
# 13  28.0    787
# 14  29.0    697
# 15  30.0    651
# 16  31.0    531
# 17  32.0    489
# 18  33.0    483
# 19  34.0    395
# 20  35.0    393
# 21  36.0    308
# 22  37.0    280
# 23  38.0    279
# 24  39.0    232
# 25  40.0    187
# 26  41.0    136
# 27  42.0    162
# 28  43.0    100
# 29  44.0     95
# 30  45.0     85
# 31  46.0     66
# 32  47.0     68
# 33  48.0     64
# 34  49.0     66
# 35  50.0     57
# 36  51.0     29
# 37  52.0     41
# 38  53.0     32
# 39  54.0     26
# 40  55.0     13
# 41  56.0     16
# 42  57.0     11
# 43  58.0     12
# 44  59.0     11
# 45  60.0      2
# 46  61.0     10
# 47  62.0      5
# 48  63.0      7
# 49  65.0      2
# 50  66.0      1
# 51  67.0      1
# 52  69.0      1
# 53  71.0      2
# 54  72.0      1
# 55  99.0      1

# %% [markdown]
# ## Demo: How to describe a table

# %%
table_name = 'master'  # the table you wish to describe

QUERY = """
SELECT sql FROM sqlite_master
WHERE name= '{}'
""".format(table_name)

df = pd.read_sql_query(QUERY,conn)
print(df.iat[0,0])
# Out:
# CREATE TABLE "master" (
# "index" INTEGER,
#   "Respondent" INTEGER,
#   "MainBranch" TEXT,
#   "Hobbyist" TEXT,
#   "OpenSourcer" TEXT,
#   "OpenSource" TEXT,
#   "Employment" TEXT,
#   "Country" TEXT,
#   "Student" TEXT,
#   "EdLevel" TEXT,
#   "UndergradMajor" TEXT,
#   "OrgSize" TEXT,
#   "YearsCode" TEXT,
#   "Age1stCode" TEXT,
#   "YearsCodePro" TEXT,
#   "CareerSat" TEXT,
#   "JobSat" TEXT,
#   "MgrIdiot" TEXT,
#   "MgrMoney" TEXT,
#   "MgrWant" TEXT,
#   "JobSeek" TEXT,
#   "LastHireDate" TEXT,
#   "FizzBuzz" TEXT,
#   "ResumeUpdate" TEXT,
#   "CurrencySymbol" TEXT,
#   "CurrencyDesc" TEXT,
#   "CompTotal" REAL,
#   "CompFreq" TEXT,
#   "ConvertedComp" REAL,
#   "WorkWeekHrs" REAL,
#   "WorkRemote" TEXT,
#   "WorkLoc" TEXT,
#   "ImpSyn" TEXT,
#   "CodeRev" TEXT,
#   "CodeRevHrs" REAL,
#   "UnitTests" TEXT,
#   "PurchaseHow" TEXT,
#   "PurchaseWhat" TEXT,
#   "OpSys" TEXT,
#   "BlockchainOrg" TEXT,
#   "BlockchainIs" TEXT,
#   "BetterLife" TEXT,
#   "ITperson" TEXT,
#   "OffOn" TEXT,
#   "SocialMedia" TEXT,
#   "Extraversion" TEXT,
#   "ScreenName" TEXT,
#   "SOVisit1st" TEXT,
#   "SOVisitFreq" TEXT,
#   "SOFindAnswer" TEXT,
#   "SOTimeSaved" TEXT,
#   "SOHowMuchTime" TEXT,
#   "SOAccount" TEXT,
#   "SOPartFreq" TEXT,
#   "SOJobs" TEXT,
#   "EntTeams" TEXT,
#   "SOComm" TEXT,
#   "WelcomeChange" TEXT,
#   "Age" REAL,
#   "Trans" TEXT,
#   "Dependents" TEXT,
#   "SurveyLength" TEXT,
#   "SurveyEase" TEXT
# )

# %% [markdown]
# # Hands-on Lab

# %% [markdown]
# ## Visualizing distribution of data

# %% [markdown]
# ### Histograms

# %% [markdown]
# Plot a histogram of `ConvertedComp.`

# %%
import matplotlib.pyplot as plt

# Connect to the SQLite database
conn = sqlite3.connect('m4_survey_data.sqlite')

# Load data into a DataFrame
df = pd.read_sql_query("SELECT ConvertedComp FROM master", conn)

# Close the connection
conn.close()

# Plot histogram
plt.figure(figsize=(10, 6))
plt.hist(df['ConvertedComp'], bins=30, color='skyblue', edgecolor='black')
plt.title('Histogram of ConvertedComp')
plt.xlabel('ConvertedComp')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Box Plots

# %% [markdown]
# Plot a box plot of `Age.`

# %%
# Connect to the SQLite database
conn = sqlite3.connect('m4_survey_data.sqlite')

# Load data into a DataFrame
df = pd.read_sql_query("SELECT Age FROM master", conn)

# Close the connection
conn.close()

# Plot box plot
plt.figure(figsize=(8, 6))
plt.boxplot(df['Age'], vert=False)
plt.title('Box Plot of Age')
plt.xlabel('Age')
plt.grid(True)
plt.show()

# %%
import seaborn as sns

# Load the dataset into a dataframe
df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m1_survey_data.csv")

# Plot boxplot for Age column
sns.boxplot(x='Age', data=df)

# Calculate Q1 and Q3
Q1 = df['Age'].quantile(0.25)
Q3 = df['Age'].quantile(0.75)

# Calculate the interquartile range (IQR)
IQR = Q3 - Q1

# Calculate the upper bound for outliers
upper_bound = Q3 + 1.5 * IQR

# Print outliers above Q3
outliers_above_Q3 = df[df['Age'] > upper_bound]
print("Outliers above Q3:")
print(outliers_above_Q3)
# Out:
# Outliers above Q3:
#        Respondent                                         MainBranch Hobbyist  \
# 50            111                     I am a developer by profession      Yes
# 139           306  I am not primarily a developer, but I write co...      Yes
# 171           375                     I am a developer by profession      Yes
# 178           392                     I am a developer by profession      Yes
# 199           429                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 11217       24357                     I am a developer by profession       No
# 11263       24466                     I am a developer by profession      Yes
# 11346       24664                     I am a developer by profession      Yes
# 11400       24786                     I am a developer by profession      Yes
# 11442       24889                     I am a developer by profession      Yes
#
#                                              OpenSourcer  \
# 50                                                 Never
# 139                              Less than once per year
# 171    Less than once a month but more than once per ...
# 178                              Less than once per year
# 199                                                Never
# ...                                                  ...
# 11217  Less than once a month but more than once per ...
# 11263                         Once a month or more often
# 11346                            Less than once per year
# 11400  Less than once a month but more than once per ...
# 11442                            Less than once per year
#
#                                               OpenSource          Employment  \
# 50     The quality of OSS and closed source software ...  Employed full-time
# 139    OSS is, on average, of HIGHER quality than pro...  Employed full-time
# 171    OSS is, on average, of HIGHER quality than pro...  Employed full-time
# 178    The quality of OSS and closed source software ...  Employed full-time
# 199    OSS is, on average, of LOWER quality than prop...  Employed full-time
# ...                                                  ...                 ...
# 11217  The quality of OSS and closed source software ...  Employed full-time
# 11263  OSS is, on average, of HIGHER quality than pro...  Employed full-time
# 11346  The quality of OSS and closed source software ...  Employed full-time
# 11400  The quality of OSS and closed source software ...  Employed full-time
# 11442  The quality of OSS and closed source software ...  Employed full-time
#
#               Country Student                                      EdLevel  \
# 50      United States      No     Bachelor’s degree (BA, BS, B.Eng., etc.)
# 139         Australia      No                             Associate degree
# 171         Australia      No     Bachelor’s degree (BA, BS, B.Eng., etc.)
# 178     United States      No     Bachelor’s degree (BA, BS, B.Eng., etc.)
# 199     United States      No     Bachelor’s degree (BA, BS, B.Eng., etc.)
# ...               ...     ...                                          ...
# 11217  United Kingdom      No     Bachelor’s degree (BA, BS, B.Eng., etc.)
# 11263   United States      No     Bachelor’s degree (BA, BS, B.Eng., etc.)
# 11346   United States      No  Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 11400   United States      No     Bachelor’s degree (BA, BS, B.Eng., etc.)
# 11442   United States      No  Master’s degree (MA, MS, M.Eng., MBA, etc.)
#
#                                           UndergradMajor  ...  \
# 50     Computer science, computer engineering, or sof...  ...
# 139    Computer science, computer engineering, or sof...  ...
# 171    Computer science, computer engineering, or sof...  ...
# 178    Computer science, computer engineering, or sof...  ...
# 199    A social science (ex. anthropology, psychology...  ...
# ...                                                  ...  ...
# 11217  A natural science (ex. biology, chemistry, phy...  ...
# 11263  A humanities discipline (ex. literature, histo...  ...
# 11346  Computer science, computer engineering, or sof...  ...
# 11400  Computer science, computer engineering, or sof...  ...
# 11442  Another engineering discipline (ex. civil, ele...  ...
#
#                                   WelcomeChange  \
# 50     Somewhat less welcome now than last year
# 139       A lot more welcome now than last year
# 171     Just as welcome now as I felt last year
# 178     Just as welcome now as I felt last year
# 199     Just as welcome now as I felt last year
# ...                                         ...
# 11217   Just as welcome now as I felt last year
# 11263   Just as welcome now as I felt last year
# 11346   Just as welcome now as I felt last year
# 11400   Just as welcome now as I felt last year
# 11442   Just as welcome now as I felt last year
#
#                                             SONewContent   Age Gender Trans  \
# 50             Tech articles written by other developers  54.0    Man    No
# 139                                                  NaN  51.0    Man    No
# 171    Tech articles written by other developers;Tech...  57.0    Man    No
# 178    Tech meetups or events in your area;Courses on...  52.0    Man    No
# 199    Tech articles written by other developers;Indu...  51.0    Man    No
# ...                                                  ...   ...    ...   ...
# 11217          Tech articles written by other developers  63.0    Man    No
# 11263  Tech articles written by other developers;Tech...  52.0    Man    No
# 11346                Tech meetups or events in your area  52.0    Man    No
# 11400       Courses on technologies you're interested in  54.0    Man    No
# 11442  Tech articles written by other developers;Tech...  52.0    NaN    No
#
#                      Sexuality  \
# 50     Straight / Heterosexual
# 139                   Bisexual
# 171    Straight / Heterosexual
# 178    Straight / Heterosexual
# 199    Straight / Heterosexual
# ...                        ...
# 11217  Straight / Heterosexual
# 11263  Straight / Heterosexual
# 11346                 Bisexual
# 11400  Straight / Heterosexual
# 11442                      NaN
#
#                                                Ethnicity Dependents  \
# 50                          White or of European descent        Yes
# 139                         White or of European descent        Yes
# 171                         White or of European descent        Yes
# 178                         White or of European descent         No
# 199                         White or of European descent        Yes
# ...                                                  ...        ...
# 11217                       White or of European descent        Yes
# 11263                       White or of European descent        Yes
# 11346                       White or of European descent         No
# 11400  Native American, Pacific Islander, or Indigeno...        Yes
# 11442                                                NaN        Yes
#
#                 SurveyLength                  SurveyEase
# 50                  Too long                        Easy
# 139    Appropriate in length                        Easy
# 171    Appropriate in length                        Easy
# 178    Appropriate in length  Neither easy nor difficult
# 199    Appropriate in length                        Easy
# ...                      ...                         ...
# 11217  Appropriate in length                        Easy
# 11263  Appropriate in length                        Easy
# 11346  Appropriate in length  Neither easy nor difficult
# 11400  Appropriate in length                        Easy
# 11442               Too long                        Easy
#
# [224 rows x 85 columns]

# %% [markdown]
# ## Visualizing relationships in data

# %% [markdown]
# ### Scatter Plots

# %% [markdown]
# Create a scatter plot of `Age` and `WorkWeekHrs.`

# %%
# Connect to the SQLite database
conn = sqlite3.connect('m4_survey_data.sqlite')

# Load data into a DataFrame
df = pd.read_sql_query("SELECT Age, WorkWeekHrs FROM master", conn)

# Close the connection
conn.close()

# Plot scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(df['Age'], df['WorkWeekHrs'], alpha=0.5, color='blue')
plt.title('Scatter Plot of Age vs WorkWeekHrs')
plt.xlabel('Age')
plt.ylabel('WorkWeekHrs')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Bubble Plots

# %% [markdown]
# Create a bubble plot of `WorkWeekHrs` and `CodeRevHrs`, use `Age` column as bubble size.

# %%
# your code goes here
#Connect to the SQLite database
conn = sqlite3.connect('m4_survey_data.sqlite')

# Load data into a DataFrame
df = pd.read_sql_query("SELECT Age, WorkWeekHrs, CodeRevHrs FROM master", conn)

# Close the connection
conn.close()

# Define bubble size
bubble_size = df['Age']

# Plot bubble plot
plt.figure(figsize=(10, 8))
plt.scatter(df['WorkWeekHrs'], df['CodeRevHrs'], s=bubble_size, alpha=0.5, color='skyblue')
plt.title('Bubble Plot of WorkWeekHrs vs CodeRevHrs')
plt.xlabel('WorkWeekHrs')
plt.ylabel('CodeRevHrs')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Visualizing composition of data

# %% [markdown]
# ### Pie Charts

# %% [markdown]
# Create a pie chart of the top 5 databases that respondents wish to learn next year. Label the pie chart with database names. Display percentages of each database on the pie chart.

# %%
# your code goes here
# Connect to the SQLite database
conn = sqlite3.connect('m4_survey_data.sqlite')

# Load data into a DataFrame
df = pd.read_sql_query("SELECT * FROM DatabaseDesireNextYear", conn)

# Close the connection
conn.close()

# Count occurrences of each database
database_counts = df['DatabaseDesireNextYear'].value_counts()

# Select top 5 databases
top_5_databases = database_counts.head()

# Create pie chart
plt.figure(figsize=(8, 8))
plt.pie(top_5_databases, labels=top_5_databases.index, autopct='%1.1f%%', startangle=140)
plt.title('Top 5 Databases Respondents Wish to Learn Next Year')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %% [markdown]
# ### Stacked Charts

# %% [markdown]
# Create a stacked chart of median `WorkWeekHrs` and `CodeRevHrs` for the age group 30 to 35.

# %%
# Connect to the SQLite database
conn = sqlite3.connect('m4_survey_data.sqlite')

# Query data for the age group 30 to 35
query = """
    SELECT Age, WorkWeekHrs, CodeRevHrs
    FROM master
    WHERE Age >= 30 AND Age <= 35
"""

# Load data into a DataFrame
df = pd.read_sql_query(query, conn)

# Close the connection
conn.close()

# Group data by Age and calculate median WorkWeekHrs and CodeRevHrs
median_data = df.groupby('Age').median()

# Plot stacked chart
plt.figure(figsize=(10, 6))
plt.bar(median_data.index, median_data['WorkWeekHrs'], label='WorkWeekHrs', color='skyblue')
plt.bar(median_data.index, median_data['CodeRevHrs'], bottom=median_data['WorkWeekHrs'], label='CodeRevHrs', color='orange')
plt.xlabel('Age')
plt.ylabel('Median Hours')
plt.title('Median WorkWeekHrs and CodeRevHrs for Age Group 30 to 35')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Visualizing comparison of data

# %% [markdown]
# ### Line Chart

# %% [markdown]
# Plot the median `ConvertedComp` for all ages from 45 to 60.

# %%
# your code goes here

print(df.columns)
# Out:
# Index(['Age', 'WorkWeekHrs', 'CodeRevHrs'], dtype='object')

# %%
df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m1_survey_data.csv")

# Filter data for ages from 45 to 60
filtered_df = df[(df['Age'] >= 45) & (df['Age'] <= 60)]

# Calculate median ConvertedComp for each age
median_converted_comp = filtered_df.groupby('Age')['ConvertedComp'].median()

# Plot the median ConvertedComp against each age
plt.figure(figsize=(10, 6))
plt.plot(median_converted_comp.index, median_converted_comp.values, marker='o', color='skyblue', linestyle='-')
plt.title('Median ConvertedComp for Ages 45 to 60')
plt.xlabel('Age')
plt.ylabel('Median ConvertedComp')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Bar Chart

# %% [markdown]
# Create a horizontal bar chart using column `MainBranch.`

# %%
# your code goes here

# Load the dataset into a dataframe
df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m1_survey_data.csv")

# Count the occurrences of each value in the MainBranch column
main_branch_counts = df['MainBranch'].value_counts()

# Plot horizontal bar chart
plt.figure(figsize=(10, 6))
main_branch_counts.plot(kind='barh', color='skyblue')
plt.title('Distribution of Main Branches')
plt.xlabel('Count')
plt.ylabel('Main Branch')
plt.show()

# %% [markdown]
# Close the database connection.

# %%
conn.close()

# %% [markdown]
# ## Authors

# %% [markdown]
# Ramesh Sannareddy

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja

# %% [markdown]
# ## Change Log

# %% [markdown]
# | Date (YYYY-MM-DD) | Version | Changed By        | Change Description                 |
# | ----------------- | ------- | ----------------- | ---------------------------------- |
# | 2020-10-17        | 0.1     | Ramesh Sannareddy | Created initial version of the lab |

# %% [markdown]
#  Copyright © 2020 IBM Corporation. This notebook and its source code are released under the terms of the [MIT License](https://cognitiveclass.ai/mit-license?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork928-2023-01-01&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ).
